# %% [markdown]
# ## Loading libraries

# %%
# Load libraries
import matplotlib.pyplot as plt # Library used for plotting
from matplotlib.patches import Rectangle # module to plot a rectangle in the image
import numpy as np # library for array manipulation
import seaborn as sn # plotting library
import pandas as pd # data frames library
import tifffile # library to store numpy arrays in TIFF
import skimage # Library for image manipulation
from skimage.io import imread # sublibrary from skimage
from scipy.ndimage import gaussian_filter
from skimage.filters import difference_of_gaussians
from skimage import transform
import os

# %%
import ipywidgets as widgets # Importing library
from ipywidgets import interact, interactive, HBox, Layout, VBox #  importing modules and functions.

# %% [markdown]
# ## Download image files
# Do NOT push the image files to your GitHub repository! This notebook with the rendered images is okay.

# %%
if not os.path.exists("./FISH_example.tif"):
   # !wget -O FISH_example.tif "https://www.dropbox.com/s/669j6zags6xd7gr/FISH_example.tif?dl=1"
# Out:
# --2023-03-13 23:38:59--  https://www.dropbox.com/s/669j6zags6xd7gr/FISH_example.tif?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601f:18::a27d:912
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/669j6zags6xd7gr/FISH_example.tif [following]
# --2023-03-13 23:38:59--  https://www.dropbox.com/s/dl/669j6zags6xd7gr/FISH_example.tif
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com/cd/0/get/B4PjK9C3_d4OUc1qTVlKpTWoWA1SnYFTPV2MQg7hGoGquzloZjl1h4y2d1yTl6SEJhxBoY6T7TVO51oKT0xQGF44DoZw-Xsmh7aB2zhVg7Zm319dZtB6DhfKLMa1sjHHVNPssujsRfBhEcn43pH3o5J-p4wAJutkubVBdiGyjioHTQ/file?dl=1# [following]
# --2023-03-13 23:39:00--  https://uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com/cd/0/get/B4PjK9C3_d4OUc1qTVlKpTWoWA1SnYFTPV2MQg7hGoGquzloZjl1h4y2d1yTl6SEJhxBoY6T7TVO51oKT0xQGF44DoZw-Xsmh7aB2zhVg7Zm319dZtB6DhfKLMa1sjHHVNPssujsRfBhEcn43pH3o5J-p4wAJutkubVBdiGyjioHTQ/file?dl=1
# Resolving uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com (uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:601d:15::a27d:50f
# Connecting to uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com (uc357b5b79d53ccd072a7613ded6.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24326534 (23M) [application/binary]
# Saving to: ‘FISH_example.tif’
#
# FISH_example.tif    100%[===================>]  23.20M  25.2MB/s    in 0.9s
#
# 2023-03-13 23:39:01 (25.2 MB/s) - ‘FISH_example.tif’ saved [24326534/24326534]

# %%
if not os.path.exists("./image_cell.tif"):
    # !wget -O image_cell.tif https://ndownloader.figshare.com/files/26751209
# Out:
# --2023-03-13 23:39:02--  https://ndownloader.figshare.com/files/26751209
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 52.16.102.173, 54.217.124.219, 2a05:d018:1f4:d003:1c8b:1823:acce:812, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|52.16.102.173|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/26751209/SupFig1c_BG_MAX_Cell04.tif?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230313/eu-west-1/s3/aws4_request&X-Amz-Date=20230313T233902Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=cd3634859b151ae4b2c59ad3683542e61aa26b0a26a134c035214e6ce6e7cc1a [following]
# --2023-03-13 23:39:02--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/26751209/SupFig1c_BG_MAX_Cell04.tif?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230313/eu-west-1/s3/aws4_request&X-Amz-Date=20230313T233902Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=cd3634859b151ae4b2c59ad3683542e61aa26b0a26a134c035214e6ce6e7cc1a
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.56.59, 52.218.24.147, 52.92.32.120, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.56.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55063679 (53M) [image/tiff]
# Saving to: ‘image_cell.tif’
#
# image_cell.tif      100%[===================>]  52.51M  21.3MB/s    in 2.5s
#
# 2023-03-13 23:39:05 (21.3 MB/s) - ‘image_cell.tif’ saved [55063679/55063679]

# %%
# reading the image and saving as variable img
img = imread('./image_cell.tif')
img.shape
# Out:
# (35, 512, 512, 3)

# %%
# Task 1
## make an image `img1` from just the red channel (channel 0) at time point 23 of the tensor [T,Y,X,C]  

# add your code here
img1 = img[23,:,:,0] # change as appropriate

img1
# Out:
# array([[114, 108,  69, ..., 145,  59,  48],
#        [ 75, 112,  92, ...,  62, 100,  38],
#        [101, 121, 124, ...,  77, 111,  50],
#        ...,
#        [ 73, 102, 111, ..., 108, 165, 131],
#        [ 60,  60,  51, ..., 142,  77,  97],
#        [102,  80, 100, ..., 153,  73,  82]], dtype=uint16)

# %%
# Task 2
## Using `img1`, create a new image `img2` where values less than than the mean are set to the 
## background value (calculated as the minimum intensity value in the image).

img2 = img1.copy()
img2[img2<np.mean(img2)]=np.mean(img2)

# plot the results
# Side-by-side comparizon
fig, ax = plt.subplots(1,2, figsize=(15, 7))
ax[0].imshow(img1,cmap='gray')
ax[0].set(title='Original')

ax[1].imshow(img2,cmap='gray')
ax[1].set_title('Threshold')
plt.show()

# %% [markdown]
# ### Task 3.
#
#    - Set `img2[0:20,0:20] = np.amax(img2)` (Make a white box in the image to more easily visualize the transformation)
#    - Compress `img2` in half, rotate it 30 degrees clockwise, and translate its `(0,0)` to `(dx,dy)=(200,100)`
#    - Save resulting image as `img3`
#    - Plot `img3` side-by-side with `img2`

# %%
# Make a white box

img2[0:20,0:20] = np.amax(img2)

from skimage import transform

#  transformation matrix
tform = transform.SimilarityTransform(translation=(200, 100))
    
    # modify as appropriate
    # float, scaling value
    # Rotation angle in counter-clockwise direction as radians. pi/180 rad = 1 degrees
    # (dx, dy) values for translation      
print('Transformation matrix : \n', tform.params , '\n')

# Apply the transformation
img3 = img1 # modify as appropriate

# plot the results
# Side-by-side comparizon
fig, ax = plt.subplots(1,2, figsize=(20, 10))
ax[0].imshow(img2,cmap='gray')
ax[0].set(title='Original')
ax[1].imshow(img3,cmap='gray')
ax[1].set_title('transformation')
plt.show()
# Out:
# Transformation matrix :
#  [[  1.  -0. 200.]
#  [  0.   1. 100.]
#  [  0.   0.   1.]]

# %% [markdown]
# ### Task 5.
#
#    - Make a slice of `img_FISH` and save as `img_FISH_slice` using: `Z=10`, `Y=120:350`, `X=50:250`
#    - Apply a Gaussian filter to `img_FISH_slice` with `sigma=1` and save it as `img_gaussian_filter_simga_1`
#    - Make difference of Gaussians filter of `img_FISH_slice` using `low_sigma=1` and `high_sigma=5` and `img_diff_gaussians`
#    - Plot all 3 images side-by-side (in 3 subplots).

# %%
# importing the FISH image as variable img_FISH
img_FISH = imread('./FISH_example.tif') 

from scipy.ndimage import gaussian_filter
from skimage.filters import difference_of_gaussians

# Make a slice of the sequence of images
img_FISH_slice = img_FISH[10,120:350,50:250]# modify as appropriate
img_gaussian_filter_simga_1 = gaussian_filter(img_FISH_slice, sigma=1) # modify as appropriate
img_diff_gaussians = difference_of_gaussians(img_FISH_slice,low_sigma=1, high_sigma=5) # modify as appropriate

# %%
# The code below should plot your results for Task 5 once the variables are defined correctly
if img_diff_gaussians != []:
    fig, ax = plt.subplots(1,3, figsize=(20, 10))
    ax[0].imshow(img_FISH_slice,cmap='gray')
    ax[0].set(title='sliced img FISH z = 10, original')
    ax[1].imshow(img_gaussian_filter_simga_1,cmap='gray')
    ax[1].set(title='Gaussian kernel $\sigma$ =1')
    ax[2].imshow(img_diff_gaussians,cmap='gray')
    ax[2].set(title='diff Gaussian kernel $\sigma$ =1,3')
    plt.show()
# Out:
# <ipython-input-28-231c3d815a17>:2: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if img_diff_gaussians != []:
